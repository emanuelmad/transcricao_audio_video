# %%
import openai
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

client = openai.OpenAI()

# %% [markdown]
# ## Transcrição de Áudio

# %%
arquivo_audio = open('/Users/emanuelsilva/Downloads/google_drive/eas_transcripts/Capitulo1_01-vimeo-834445655-dash-fastly_skyfire_sep-audio-2569e022.m4a', mode='rb')

transcricao = client.audio.transcriptions.create(
    model='whisper-1',
    language='pt',
    response_format='text',
    file=arquivo_audio
)

print(transcricao)
# Out:
# Olá pessoal, sejam bem-vindos ao nosso primeiro capítulo do curso de visão computacional e PDI para sensoriamento remoto com Python. Então, nesse primeiro capítulo aqui, vamos fazer uma introdução básica à visão computacional. Depois, usando Python, a gente realiza algum código para abrir uma imagem, realizar alguma operação com esta imagem. Então, nesse primeiro capítulo, vamos fazer uma introdução bem básica e, nos próximos capítulos, seguimos adiante, avançando cada vez mais no conteúdo, beleza? Então, vamos primeiro ver o conceito de visão computacional. Então, o que é a visão computacional? Então, a visão computacional é um campo da área da ciência da computação e o objetivo da visão computacional é replicar tarefas que o homem realiza através da visão em máquinas. Então, detecção de objeto, as tarefas de reconhecimento de imagens. Então, a gente tem, hoje em dia, diversas aplicações que são voltadas a imagens e vídeos, que podem ser automatizadas e até simplificadas com o uso de máquinas do que em substituição à pessoa. Então, por exemplo, a detecção de falhas em estruturas. Então, você voou num drone, você pode realizar um sobrevoo através de uma estrutura e tentar identificar as falhas nesse vídeo e, a partir disso, você toma uma ação com essas informações. Então, nós vamos ver algumas aplicações mais voltadas para o sensoramento remoto, mas essa é uma área muito ampla, essa área da visão computacional e, hoje em dia, cada vez mais diversos ramos da ciência está aplicando esses algoritmos. Então, a primeira coisa que a gente tem que atentar hoje em dia é a separação entre os dois ramos da visão computacional. Então, a gente tem a visão tradicional e a visão computacional utilizando o Deep Learning. Então, qual é a ideia da abordagem tradicional? A abordagem tradicional é a visão computacional desde quando ela foi criada, nos inícios da era da computação, até meados de 2010, 2012, assim, que é, na verdade, a aplicação de diversos algoritmos de visão computacional que extraem características da imagem, primeiro, depois a gente seleciona quais são esses melhores algoritmos e aí passa para um algoritmo de Machine Learning realizar alguma classificação, como identificação de objetos em imagem, detecção de objetos em imagem. E temos também a abordagem usando o Deep Learning. Então, o que a abordagem Deep Learning fez? Ela unificou essas três operações que antes eram realizadas separadamente. Então, primeiro a gente analisava a imagem, extraia as características da imagem, dependendo de qual tarefa, depois selecionava quais características melhor representam aquela tarefa e depois aplicava um algoritmo de Machine Learning para realizar a finalização da tarefa. Hoje em dia, os algoritmos de Deep Learning, também através das redes convolucionais, já realizam esses três passos juntos, unificados dentro do próprio algoritmo das redes convolucionais e, então, o Deep Learning é uma evolução desses algoritmos mais tradicionais. Nesse curso aqui, veremos apenas essa parte tradicional dos algoritmos mais básicos, como extrair características de uma imagem, como selecionar essas características para ver qual é mais interessante e também como aplicar um classificador a partir dessas características. Mas pode estar pensando mas hoje em dia, então, se tem o Deep Learning, por que eu vou utilizar a abordagem mais tradicional? Porque o Deep Learning, a abordagem de Deep Learning, ela precisa de uma quantidade de dados enorme, então, às vezes você não tem isso, então, às vezes você precisa de uma coisa mais simples, mais rápida, com um resultado que pode ser simples, então, não compensa você treinar um algoritmo de Deep Learning, que é uma coisa complexa, pesada, demorada, para realizar uma tarefa simples, você não precisa de um canhão para matar uma mosca, então, hoje em dia, ainda se usa muito esses algoritmos de tradicionais de visão computacional, como a gente vai ver vários aqui, então, você não tem a necessidade de criar só o Deep Lear ...

# %%
transcricao = client.audio.transcriptions.create(
    model='whisper-1',
    language='pt',
    response_format='srt',

    file=arquivo_audio
)

print(transcricao)
# Out:
# 1
# 00:00:00,000 --> 00:00:04,560
# Olá pessoal, sejam bem-vindos ao nosso primeiro capítulo do curso de visão
#
# 2
# 00:00:04,560 --> 00:00:08,440
# computacional e PDI para sensoriamento remoto com Python.
#
# 3
# 00:00:08,440 --> 00:00:12,760
# Então, nesse primeiro capítulo aqui, vamos fazer uma introdução básica à visão
#
# 4
# 00:00:12,760 --> 00:00:21,559
# computacional. Depois, usando Python, a gente realiza algum código para abrir
#
# 5
# 00:00:21,559 --> 00:00:26,120
# uma imagem, realizar alguma operação com esta imagem. Então, nesse primeiro
#
# 6
# 00:00:26,120 --> 00:00:30,799
# capítulo, vamos fazer uma introdução bem básica e, nos próximos capítulos,
#
# 7
# 00:00:30,799 --> 00:00:35,200
# seguimos adiante, avançando cada vez mais no conteúdo, beleza?
#
# 8
# 00:00:35,200 --> 00:00:41,799
# Então, vamos primeiro ver o conceito de visão computacional. Então, o que é a
#
# 9
# 00:00:41,799 --> 00:00:46,759
# visão computacional? Então, a visão computacional é um campo da área da
#
# 10
# 00:00:46,759 --> 00:00:54,840
# ciência da computação e o objetivo da visão computacional é replicar tarefas
#
# 11
# 00:00:54,840 --> 00:01:00,799
# que o homem realiza através da visão em máquinas. Então, detecção de
#
# 12
# 00:01:00,799 --> 00:01:07,320
# objeto, as tarefas de reconhecimento de imagens.
#
# 13
# 00:01:07,320 --> 00:01:14,800
# Então, a gente tem, hoje em dia, diversas aplicações que são voltadas
#
# 14
# 00:01:14,800 --> 00:01:21,519
# a imagens e vídeos, que podem ser automatizadas e até simplificadas
#
# 15
# 00:01:21,519 --> 00:01:28,160
# com o uso de máquinas do que em substituição à pessoa. Então, por exemplo,
#
# 16
# 00:01:28,160 --> 00:01:33,919
# a detecção de falhas em estruturas. Então, você voou num drone, você pode
#
# 17
# 00:01:33,919 --> 00:01:40,320
# realizar um sobrevoo através de uma estrutura e tentar identificar as
#
# 18
# 00:01:40,320 --> 00:01:47,040
# falhas nesse vídeo e, a partir disso, você toma uma ação com essas
#
# 19
# 00:01:47,040 --> 00:01:52,720
# informações. Então, nós vamos ver algumas aplicações mais
#
# 20
# 00:01:52,720 --> 00:01:56,360
# voltadas para o sensoramento remoto, mas essa é uma área muito ampla, essa
#
# 21
# 00:01:56,360 --> 00:02:02,599
# área da visão computacional e, hoje em dia, cada vez mais diversos ramos da
#
# 22
# 00:02:02,599 --> 00:02:09,039
# ciência está aplicando esses algoritmos. Então, a primeira coisa que a gente tem
#
# 23
# 00:02:09,039 --> 00:02:14,600
# que atentar hoje em dia é a separação entre os dois ramos da visão
#
# 24
# 00:02:14,600 --> 00:02:19,880
# computacional. Então, a gente tem a visão tradicional e a visão computacional
#
# 25
# 00:02:19,880 --> 00:02:25,000
# utilizando o Deep Learning. Então, qual é a ideia da abordagem tradicional?
#
# 26
# 00:02:25,000 --> 00:02:30,960
# A abordagem tradicional é a visão computacional desde quando ela foi
#
# 27
# 00:02:30,960 --> 00:02:39,240
# criada, nos inícios da era da computação, até meados de 2010, 2012,
#
# 28
# 00:02:39,240 --> 00:02:45,520
# assim, que é, na verdade, a aplicação de diversos algoritmos de visão
#
# 29
# 00:02:45,520 --> 00:02:49,960
# computacional que extraem características da imagem, primeiro,
#
# 30
# 00:02:49,960 --> 00:02:55,399
# depois a gente seleciona quais são esses melhores algoritmos e aí passa para
#
# 31
# 00:02:55,399 --> 00:02:58,479
# um algoritmo de Machine Learning realizar alguma classificação, como
#
# 32
# 00:02:58,479 --> 00:03:03,720
# identificação de objetos em imagem, detecção de objetos em imagem. E temos também a
#
# 33
# 00:03:03,800 --> 00:03:09,679
# abordagem usando o Deep Learning. Então, o que a abordagem Deep Learning fez?
#
# 34
# 00:03:09,679 --> 00:03:15,440
# Ela unificou essas três operações que antes eram realizadas
#
# 35
# 00:03:15,440 --> 00:03:19,800
# separadamente. Então, primeiro a gente analisava a imagem, extraia as
#
# 36
# 00:03:19,800 --> 00:03:26,639
# características da imagem, dependendo de qual tarefa, depois selecionava
#
# 37
# 00:03:26,639 --> 00:03:32,639
# quais características melhor representam aquela tarefa e depois
#
# 38
# 00:03:32,639 --> 00:03:38,360
# aplicava um algoritmo de Machine Learning para realizar a finalização da tarefa.
#
# 39
# 00:03:38,360 --> 00:03:41,720
# Hoje em dia, os algoritmos de Deep Learning, também através das redes
#
# 40
# 00:03:41,720 --> 00:03:48,160
# convolucionais, já realizam esses três passos juntos, unificados
#
# 41
# 00:03:48,160 --> 00:03:54,559
# dentro do próprio algoritmo das redes convolucionais e, então, o Deep Learning é uma
#
# 42
# 00:03:54,559 --> 00:04:00,600
# evolução desses algoritmos mais tradicionais.
#
# 43
# 00:04:00,600 --> 00:04:04,399
# Nesse curso aqui, veremos apenas essa parte tradicional dos algoritmos mais básicos,
#
# 44
# 00:04:04,399 --> 00:04:09,679
# como extrair características de uma imagem, como selecionar essas
#
# 45
# 00:04:09,679 --> 00:04:13,520
# características para ver qual é mais interessante e também como aplicar um
#
# 46
# 00:04:13,520 --> 00:04:20,040
# classificador a partir dessas características. Mas pode estar pensando
#
# 47
# 00:04:20,040 --> 00:04:25,160
# mas hoje em dia, então, se tem o Deep Learning, por que eu vou utilizar a abordagem mais
#
# 48
# 00:04:25,160 --> 00:04:30,720
# tradicional? Porque o Deep Learning, a abordagem de Deep Learning, ela precisa de
#
# 49
# 00:04:30,720 --> 00:04:35,480
# uma quantidade de dados enorme, então, às vezes você não tem isso, então, às vezes
#
# 50
# 00:04:35,480 --> 00:04:42,880
# você precisa de uma coisa mais simples, mais rápida, com um resultado
#
# 51
# 00:04:42,880 --> 00:04:48,839
# que pode ser simples, então, não compensa você treinar um
#
# 52
# 00:04:48,839 --> 00:04:53,000
# algoritmo de Deep Learning, que é uma coisa complexa, pesada, demorada, para realizar uma
#
# 53
# 00:04:53,000 --> 00:04:57,399
# tarefa simples, você não precisa de um canhão para matar uma mosca,
#
# 54
# 00:04:57,399 --> 00:05:04,160
# então, hoje em dia, ainda se usa muito esses algoritmos de tradicionais de
#
# 55
# 00:05:04,160 --> 00:05:09,359
# visão computacional, como a gente vai ver vários aqui, então, você não tem a
#
# 56
# 00:05:09,359 --> 00:05:13,480
# necessidade de criar só o Deep Learning, você pode aprender tudo que você vai ter
#
# 57
# 00:05:13,480 --> 00:05:18,359
# locais onde usar, esses algoritmos podem se encaixar um perto de outro, num
#
# 58
# 00:05:18,359 --> 00:05:23,679
# fluxo de geração de resultados, assim, então, é importante você ter o
#
# 59
# 00:05:23,679 --> 00:05:31,320
# conhecimento dessa base dos algoritmos tradicionais também, agora vamos ver
#
# 60
# 00:05:31,320 --> 00:05:36,320
# onde se encaixa aqui, todas essas áreas, então, hoje em dia temos diversos
#
# 61
# 00:05:36,320 --> 00:05:42,040
# termos, como visão computacional, inteligência artificial, Machine Learning, Deep Learning,
#
# 62
# 00:05:42,040 --> 00:05:47,399
# redes comuns, então, o que são cada um desses termos? Então, a gente tem a área
#
# 63
# 00:05:47,399 --> 00:05:54,920
# da ciência da computação, que é uma área enorme, com várias divisões,
#
# 64
# 00:05:54,920 --> 00:06:02,160
# temos a área da inteligência artificial, que é você fazer com que a
#
# 65
# 00:06:02,160 --> 00:06:06,559
# máquina realize tarefas de uma pessoa, e uma dessas tarefas é a visão
#
# 66
# 00:06:06,559 --> 00:06:13,359
# computacional, então, é fazer com que a máquina enxerga e realize tarefas que o
#
# 67
# 00:06:13,359 --> 00:06:19,519
# ser humano faz, que o olho do ser humano faz, não só o olho, mas toda a parte de visão do
#
# 68
# 00:06:19,519 --> 00:06:25,160
# ser humano, e aí a gente tem uma intersecção entre essas áreas de Deep Learning,
#
# 69
# 00:06:25,160 --> 00:06:31,279
# Machine Learning, redes comuns para visão computacional, por que? Porque dentro da
#
# 70
# 00:06:31,279 --> 00:06:35,359
# área de Machine Learning, Deep Learning, pode ser utilizado para diversas outras
#
# 71
# 00:06:35,359 --> 00:06:40,920
# tarefas de inteligência artificial, como processamento de linguagens naturais,
#
# 72
# 00:06:40,920 --> 00:06:45,160
# então, existem algoritmos de Deep Learning voltados para tradução de texto,
#
# 73
# 00:06:45,160 --> 00:06:50,799
# processamento de textos, e temos a parte de Deep Learning voltada
#
# 74
# 00:06:50,799 --> 00:06:54,920
# para a parte de visão computacional, mas nada impede que você adapte um ou outro
#
# 75
# 00:06:54,920 --> 00:07:02,279
# algoritmo para utilizar para diversas áreas, como finanças, processamento de texto,
#
# 76
# 00:07:02,279 --> 00:07:05,000
# como eu já tinha falado.
